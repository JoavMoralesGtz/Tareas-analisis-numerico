# %% [markdown]
# PRoblema **1**

# %%
a= int (input("Dame un numero entero: ") )
b= a%2
if (b==0):
  print(f"{a} es un numero par.")
else: 
  print(f"{a} es un numero impar.")
# Out:
# Dame un numero entero: 6
# 6 es un numero par.

# %% [markdown]
# Problema 2

# %%
a= int(input("Dame un numero entero: "))
b=str (input(" Dame una cadena de caracteres: "))
c=0
print("\n")
while c<a:
  c+=1
  print(b)
# Out:
# Dame un numero entero: 5
#  Dame una cadena de caracteres: Si puedes imaginarlo, puedes programarlo
#
#
# Si puedes imaginarlo, puedes programarlo
# Si puedes imaginarlo, puedes programarlo
# Si puedes imaginarlo, puedes programarlo
# Si puedes imaginarlo, puedes programarlo
# Si puedes imaginarlo, puedes programarlo

# %% [markdown]
# Problema 3

# %%
def salario(horas, salario=150):
 sd = horas * salario
 ss= sd*5
 sm=sd*20
 print("\n")
 print("Tu salario dairio es de: ",sd)
 print("Tu salario semanal es de: ",ss)
 print("Tu salario mensual es de: ",sm)

a=int (input("Dame las horas trabajadas al dia: "))

salario (a)
# Out:
# Dame las horas trabajadas al dia: 2
#
#
# Tu salario dairio es de:  300
# Tu salario semanal es de:  1500
# Tu salario mensual es de:  6000

# %% [markdown]
# Problema 4

# %%
print("Las opciones son: ")
print("1-. Sumar")
print("2.- Restar")
print("3.- Multiplicar")
print("4.- Dividir")
print("5.- Salir")

opc= int (input("\nQue quieres hacer?: "))

if opc ==1:
  x=0
  y=0
  n= int (input("Cuantos numeros quieres sumar: "))
  while x < n:
    a= float (input("Dame el numero a sumar: "))
    y= y+a
    x=x+1
  print("La suma es: ",y)  

if opc ==2:
  x=1
  z=0
  zz=0
  zzz=0
  n= int (input("Cuantos numeros quieres restar: "))
  while x < n:
    a= float (input("Dame el numero a restar: "))
    z=a
    g= float (input("Dame el otro numero: "))
    zz=g
    zzz= a-g
    x=x+1
  print("La resta es: ",zzz)  

if opc ==3:
  x=0
  r3=1
  n= int (input("Cuantos numeros quieres multiplicar: "))
  while x < n:
    a= float (input("Dame el numero a multiplicar: "))
    r3= r3*a
    x=x+1
  print("La multiplicacion es: ",r3)

if opc ==4:
  x=0
  y=0
  n= 1
  while x < n:
    a= float (input("Dame el numerador: "))
    b= float (input("Dame el denominador: "))
    if b== 0:
      print("A ocurrido un error.")
      break
    else:
     y= a/b
     x=x+1
    print("La division es: ",y)



if opc ==5:
 print("Hemos terminado.")

if opc >=6:
  print("ERROR. Lo sentimos.")
# Out:
# Las opciones son:
# 1-. Sumar
# 2.- Restar
# 3.- Multiplicar
# 4.- Dividir
# 5.- Salir
#
# Que quieres hacer?: 4
# Dame el numerador: 5
# Dame el denominador: 0
# A ocurrido un error.

# %% [markdown]
# Problema 5

# %%
def peso (payasos, mesa):
  ppayaso= 150
  pmesa=170
  pp= payasos*ppayaso
  pm= mesa*pmesa
  pt= pp+pm
  ps=pt-10000
  
  if pt>10000:
   print("El peso total sobre pasa los 10kg:")
   print(f"Te pasas por {ps} g.")
  else:
    print(f"El peso total es de {pt}, continua.")

a=int (input("Cuantos payasos son?: "))
b= int (input("Cuantos juegos de mesa son?: "))

peso (a,b)
# Out:
# Cuantos payasos son?: 70
# Cuantos juegos de mesa son?: 1
# El peso total sobre pasa los 10kg:
# Te pasas por 670 g.

# %% [markdown]
# Problema 6

# %%
def impuesto (salario):
  if salario <= 10000:
    print("\nTu rango es de menos de 10 mil.")
    i=salario*.05
    print("El impuesto a pagar es de: ",i)
  
  if salario >= 10001 and salario <= 15000:
    print("\nTu rango es de entre 10 mil y 15 mil.")
    i=salario*.05
    print("El mpuesto a pagar es de: ",i)

  if salario >= 15001 and salario <= 20000:
    print("\nTu rango es de entre 15 mil y 20 mil.")
    i=salario*.05
    print("El mpuesto a pagar es de: ",i)

  if salario >= 20001:
    print("\nTu rango es de mas de 20 mil.")
    i=salario*.05
    print("El mpuesto a pagar es de: ",i)
  

a= float (input("Cual es tu salario?: "))

impuesto(a)
# Out:
# Cual es tu salario?: 25000
#
# Tu rango es de mas de 20 mil.
# El mpuesto a pagar es de:  1250.0

# %% [markdown]
# Problema 7

# %%
def museo (edad, ocupacion):
  x=50
  y=100

  if edad <= 4:
    print("Tu entrada es GRATIS.")

  if edad >=5 and edad <=16:
    print(f"Tu entrada es de ${x}.")
    if c =='si':
     if ocupacion == 'estudiante':
       d= x*.10
       des= x-d
       print("Por ser estudiante tu entrada es de: ",des)
     if ocupacion == 'docente':
       d= x*.30
       des=x-d
       print("Por ser docente tu entrada es de: ",des)
     if ocupacion == 'inapam':
       d= x*.50
       des=x-d
       print("Por ser INAPAM tu entrada es de: ",des)
    else:
      print("no hay descuento.")

  if edad >= 17:
    print(f"Edad adulto. Tu entrada es de ${y}.")
    if c == 'si':
     if ocupacion == 'estudiante':
       d= y*.10
       des= y-d
       print("Por ser estudiante tu entrada es de: ",des)
     if ocupacion == 'docente':
       d= y*.30
       des=y-d
       print("Por ser docente tu entrada es de: ",des)
     if ocupacion == 'inapam':
       d= y*.50
       des=y-d
       print("Por ser INAPAM tu entrada es de: ",des)
    else: 
      print("No hay descuento.")

a=float (input("Cual es tu edad?: "))
b= str (input("Cual es tu ocupacion?: "))
c= str (input("Trae credencial?: "))

museo(a,b)
# Out:
# Cual es tu edad?: 19
# Cual es tu ocupacion?: inapam
# Trae credencial?: si
# Edad adulto. Tu entrada es de $100.
# Por ser INAPAM tu entrada es de:  50.0

# %% [markdown]
# Problema 8

# %%
f= int (input("Dame el numero de renglones: "))
for i in range (f+1):
  print("*"*i)
# Out:
# Dame el numero de renglones: 4
#
# *
# **
# ***
# ****

# %% [markdown]
# Problema 9

# %%
def factorial (a):
  if a== 0:
    return 1

  else: 
    return a*factorial(a-1)
    
a= int (input("Dame un numero entero: "))
print("El factorial de " + str (a) + " es: "+ str (factorial(a)))
# Out:
# Dame un numero entero: 0
# El factorial de 0 es: 1

# %% [markdown]
# Problema 10

# %%
r= float (input("Cual es el radio del circulo?:"))

pi= 3.1416
area= pi*(r**2)

print("\nEl area del circulo es de: ",area)
print("\nAhora calculemos el volumen de un cilindro.")
print(f"Tomemos el radio dado del circulo como {r}.")
a= float (input("\nDame el dato faltante (La altura): "))

vc= area*a

print("\nEl volumen del cilindro seria de: " ,vc)
# Out:
# Cual es el radio del circulo?:5
#
# El area del circulo es de:  78.53999999999999
#
# Ahora calculemos el volumen de un cilindro.
# Tomemos el radio dado del circulo como 5.0.
#
# Dame el dato faltante (La altura): 2
#
# El volumen del cilindro seria de:  157.07999999999998
